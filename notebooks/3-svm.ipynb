# %%
import pandas as pd
import numpy as np

# %%
from sklearn.svm import SVC

# %% [markdown]
# ## Get data

# %%
drugs_df = pd.read_csv('../data/processed/drugs_filtered.tsv', sep='\t', index_col=0)

# %%
drugs_df = drugs_df[['pog_id', 'drug_name', 'cancer_cohort', 'zscore', 'days_on_tx_since_biopsy']]

# %%
expression_df = pd.read_csv('../data/processed/expression_tpm_log.tsv')
# Out:
#       pog_id        drug_name cancer_cohort    zscore  days_on_tx_since_biopsy
# 0     POG864       TRAMETINIB            OV -0.589448                       83
# 2     POG122       IRINOTECAN          COLO -0.365267                      112
# 3     POG878       IRINOTECAN          PANC -0.845827                       14
# 4     POG175      GEMCITABINE          BRCA -0.706151                       28
# 5     POG270      GEMCITABINE           HCC  0.463352                      148
# 6     POG804      GEMCITABINE          BRCA -0.832847                       15
# 9     POG049  FLUDROCORTISONE           ACC -0.707107                      174
# 13    POG638       BMS-986205          LYMP -0.726953                       28
# 14    POG381        GEFITINIB          LUNG  1.637037                      462
# 17    POG092       PACLITAXEL          BRCA -0.536654                       59
# 18    POG611       PACLITAXEL          BRCA  1.138689                      210
# 21    POG926         ERIBULIN          SARC  0.579955                      101
# 23    POG602        CISPLATIN          MISC -0.635305                       35
# 32    POG078     CAPECITABINE          BRCA  0.137474                      163
# 35    POG419      DOXORUBICIN          BRCA -0.719273                       35
# 38    POG855      DOXORUBICIN          BRCA -0.719273                       35
# 39    POG887     CAPECITABINE          BRCA  0.013924                      146
# 44    POG922       EXEMESTANE          BRCA -0.010420                      119
# 47    POG302       IRINOTECAN          COLO  3.337008                      867
# 48    POG357       IRINOTECAN          PANC  2.537709                      704
# 49    POG496       IRINOTECAN          COLO  1.694277                      532
# 50    POG312      GEMCITABINE          SARC  0.102755                      111
# 51    POG405      GEMCITABINE          UCEC  0.317164                      133
# 52    POG663      GEMCITABINE            OV -0.023941                       98
# 53    POG878      GEMCITABINE          PANC  0.940898                      197
# 56    POG518     CAPECITABINE          COLO -0.502079                       75
# 59    POG022       EVEROLIMUS          BRCA  0.084154                      146
# 62    POG775     FLUOROURACIL          COLO  0.716453                      316
# 65    POG410      CARBOPLATIN          BRCA -0.787752                       35
# 66    POG347        ETOPOSIDE          SARC -0.577150                       47
# ...      ...              ...           ...       ...                      ...
# 3296  POG491      BEVACIZUMAB          COLO -0.903627                       33
# 3297  POG569      BEVACIZUMAB          COLO -0.597598                       98
# 3298  POG712      BEVACIZUMAB          COLO  0.061542                      238
# 3299  POG513        MEGESTROL          COLO -0.707107                       21
# 3300  POG032       PACLITAXEL          BRCA -0.725269                       42
# 3301  POG034       PACLITAXEL          BRCA -0.170519                       92
# 3302  POG041       PACLITAXEL          UCEC -0.026285                      105
# 3304  POG884       IRBESARTAN          ESCA  0.534628                       67
# 3307  POG398        CISPLATIN          ESCA  1.176258                      230
# 3309  POG399      PALBOCICLIB          PANC -0.508173                      120
# 3311  POG855       RIBOCICLIB          BRCA  0.707107                      156
# 3313  POG448       EXEMESTANE          BRCA -0.184086                       94
# 3316  POG129       IRINOTECAN          COLO -0.708524                       42
# 3317  POG819       IRINOTECAN          COLO  0.321248                      252
# 3320  POG099       EXEMESTANE          BRCA -0.524473                       45
# 3322  POG426      GEMCITABINE          PANC -0.530725                       46
# 3323  POG482      GEMCITABINE          BRCA -0.910813                        7
# 3325  POG761     CAPECITABINE          BRCA -0.371261                       93
# 3330  POG316     FLUOROURACIL          COLO  1.483706                      462
# 3336  POG594       DURVALUMAB          BRCA -0.941745                       21
# 3337  POG710       DURVALUMAB          PANC -0.128804                       98
# 3338  POG517       LEUCOVORIN          CHOL -0.729921                       41
# 3339  POG605       LEUCOVORIN          COLO  0.920007                      337
# 3341  POG034       PACLITAXEL          BRCA -1.035928                       14
# 3343  POG166       PACLITAXEL          ESCA -1.035928                       14
# 3344  POG385       PACLITAXEL          BRCA -0.081759                      100
# 3345  POG405       PACLITAXEL          UCEC  0.528465                      155
# 3348  POG107       PERTUZUMAB          BRCA  1.476111                     1283
# 3353  POG684      PALBOCICLIB          BRCA  1.193569                      315
# 3354  POG761      PALBOCICLIB          BRCA -0.150371                      161
#
# [1496 rows x 5 columns]
