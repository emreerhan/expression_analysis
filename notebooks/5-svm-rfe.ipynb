# %%
_random_seed_ = 42

# %%
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt

# %%
expression_minmax_df = pd.read_csv('../data/processed/expression_tpm_minmax.tsv', sep='\t', index_col=0)

# %%
expression_minmax_df = expression_minmax_df.set_index('pog_id')

# %%
drugs_df = pd.read_csv('../data/processed/drugs_filtered.tsv', sep='\t', index_col=0)

# %%
drugs_selected_df = drugs_df[['pog_id', 'drug_name', 'days_on_tx_since_biopsy', 'cancer_cohort']]

# %% [markdown]
# # Prepare features and labels

# %% [markdown]
# ## Join drugs and expression tables

# %%
drugs_expression_df = drugs_selected_df.join(expression_minmax_df, on='pog_id', how='inner')

# %%
drugs_expression_df = drugs_expression_df.drop_duplicates()

# %% [markdown]
# Number of drug types and their names

# %% [markdown]
# ## Select cancer type and drug
# decide based on notebook 0

# %%
cancer_types = np.unique(drugs_expression_df['cancer_cohort'])

# %%
drug_names = np.unique(drugs_expression_df['drug_name'])

# %%
drugs_expression_sel_df = drugs_expression_df[(drugs_expression_df['cancer_cohort'] == 'BRCA') & (drugs_expression_df['drug_name'] == 'CISPLATIN')]
# drugs_expression_sel_df = drugs_expression_df[(drugs_expression_df['cancer_cohort'] == 'LYMP')]

# %%
drugs_expression_sel_df
# Out:
#       pog_id  drug_name  days_on_tx_since_biopsy cancer_cohort  \
# 260   POG175  CISPLATIN                       28          BRCA
# 470   POG804  CISPLATIN                       15          BRCA
# 2413  POG419  CISPLATIN                       19          BRCA
# 79    POG056  CISPLATIN                       53          BRCA
# 775   POG311  CISPLATIN                       98          BRCA
# 133   POG304  CISPLATIN                      114          BRCA
# 2215  POG061  CISPLATIN                      183          BRCA
# 2672  POG131  CISPLATIN                       90          BRCA
# 213   POG141  CISPLATIN                       72          BRCA
# 2674  POG890  CISPLATIN                      112          BRCA
# 1723  POG744  CISPLATIN                      113          BRCA
# 2614  POG716  CISPLATIN                        7          BRCA
# 2410  POG074  CISPLATIN                      155          BRCA
# 420   POG042  CISPLATIN                      310          BRCA
# 1333  POG128  CISPLATIN                       35          BRCA
# 1236  POG579  CISPLATIN                        8          BRCA
# 1265  POG099  CISPLATIN                        7          BRCA
# 2873  POG369  CISPLATIN                       71          BRCA
# 935   POG027  CISPLATIN                      477          BRCA
# 1235  POG502  CISPLATIN                        7          BRCA
# 655   POG032  CISPLATIN                       85          BRCA
# 710   POG356  CISPLATIN                      611          BRCA
# 2822  POG723  CISPLATIN                       85          BRCA
# 3031  POG438  CISPLATIN                       56          BRCA
# 1776  POG375  CISPLATIN                       43          BRCA
# 1830  POG010  CISPLATIN                      115          BRCA
# 1565  POG023  CISPLATIN                      155          BRCA
# 2412  POG359  CISPLATIN                      196          BRCA
# 2580  POG625  CISPLATIN                      131          BRCA
# 2874  POG594  CISPLATIN                      176          BRCA
# 2517  POG936  CISPLATIN                      106          BRCA
# 1231  POG002  CISPLATIN                       57          BRCA
# 3200  POG665  CISPLATIN                      119          BRCA
# 2995  POG298  CISPLATIN                        7          BRCA
# 1332  POG031  CISPLATIN                      285          BRCA
# 1622  POG374  CISPLATIN                       60          BRCA
# 2874              0.0
# 2517              0.0
# 1231              0.0
# 3200              0.0
# 2995              0.0
# 1332              0.0
# 1622              0.0
# 1831              0.0
# 1611              0.0
# 1773              0.0
# 1909              0.0
# 2499              0.0
# 2079              0.0
# 2248              0.0
#
# [43 rows x 58054 columns]

# %%
len(np.unique(drugs_expression_sel_df['pog_id']))
# Out:
# 43

# %% [markdown]
# ## Set features (X) and labels (y)

# %%
X = drugs_expression_sel_df.loc[:, expression_minmax_df.columns]

# %%
y = drugs_expression_sel_df.loc[:, 'days_on_tx_since_biopsy']

# %% [markdown]
# ## Power transform on y

# %%
from sklearn.preprocessing import PowerTransformer

# %%
power_transformer = PowerTransformer(method='box-cox', standardize=True)

# %%
y_trans = power_transformer.fit_transform(y.values.reshape(-1, 1))[:, 0]

# %% [markdown]
# ## Naive feature selection: Variance threshold

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
variance_selector = VarianceThreshold(threshold=0.01)

# %%
X_selected = variance_selector.fit_transform(X)

# %%
X_selected.shape
# Out:
# (43, 9953)

# %%
selected_columns = X.columns[variance_selector.get_support()]

# %%
X_selected_df = pd.DataFrame(data=X_selected, columns=selected_columns, index=X.index)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_selected_df, y_trans, test_size=0.25, random_state=_random_seed_)
# X_train, X_test, y_train, y_test = train_test_split(X, y_trans, test_size=0.25, random_state=_random_seed_)

# %% [markdown]
# # Recursive Feature Selection

# %%
from sklearn.feature_selection import RFE

# %%
from sklearn.svm import LinearSVR

# %%
num_features = math.floor(len(X_selected_df.columns)/20)

# %%
num_features = 2000

# %%
svr = LinearSVR(max_iter=10000)

# %%
selector = RFE(svr, num_features, step=0.01, verbose=0)

# %%
selector = selector.fit(X_train, y_train)

# %%
selector.score(X_test, y_test)
# Out:
# 0.17781005673145567

# %%
svr.fit(X_train, y_train)
# Out:
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#      intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=10000,
#      random_state=None, tol=0.0001, verbose=0)

# %%
svr.score(X_test, y_test)
# Out:
# 0.12051862185100981

# %%
drugs_expression_df['drug_name'] == 'FLUOROURACIL'
# Out:
# 0       False
# 1911    False
# 2       False
# 1024     True
# 1152     True
# 1324    False
# 1562    False
# 1652    False
# 1802    False
# 1934    False
# 2931    False
# 3       False
# 53      False
# 1595    False
# 2634     True
# 2942    False
# 4       False
# 260     False
# 5       False
# 871     False
# 2134    False
# 6       False
# 470     False
# 1223    False
# 9       False
# 506     False
# 1455    False
# 2341    False
# 13      False
# 638     False
#         ...
# 2731    False
# 2760    False
# 3167    False
# 3317    False
# 2776    False
# 2801    False
# 2806    False
# 2814    False
# 2852    False
# 2886    False
# 2903    False
# 2908    False
# 3325    False
# 3354    False
# 2914    False
# 3148    False
# 2920    False
# 2960    False
# 2994    False
# 3202    False
# 3017    False
# 3132    False
# 3155    False
# 3159    False
# 3222    False
# 3248    False
# 3299    False
# 3301    False
# 3341    False
# 3304    False
# Name: drug_name, Length: 1494, dtype: bool

# %%
test = [(1,2), (3,4), (5,6)]
test2 = [1,2,3]

# %%
for i, j in zip(test, test2):
    a, b = i
    print(a,b)
# Out:
# 1 2
# 3 4
# 5 6
